# %%
import pulp as lp
import pandas as pd

# %%
# Store results for all countries
optimization_results = {}

# Load the processed data from CSV
final_df = pd.read_csv("Final_Processed_Data.csv")

# Iterate through each country
for country in final_df["Country"].unique():
    # Filter data for the specific country
    country_df = final_df[final_df["Country"] == country]

    # Extract parameters
    advertiser_data = country_df[["Month", "Advertisers", "Avg_Budget"]].reset_index(drop=True)
    initial_agents = country_df["Existing_Agent_Count"].iloc[0]
    annual_salary = country_df["Annual_Agent_Salary_USD"].iloc[0]
    monthly_salary = annual_salary / 12

    # Constants
    firing_cost_perc = 0.4
    max_adv_per_agent = 10
    expected_uplift = 0.135
    n_months = len(advertiser_data)

    # Initialize PuLP problem
    prob = lp.LpProblem(f"Dynamic_Staffing_Optimization_{country}", lp.LpMinimize)

    # Decision Variables
    months = list(range(n_months))
    A = lp.LpVariable.dicts("Available_Agents", months, lowBound=0, cat='Integer')
    N = lp.LpVariable.dicts("New_Hires", months, lowBound=0, cat='Integer')
    F = lp.LpVariable.dicts("Fired", months, lowBound=0, cat='Integer')
    S = lp.LpVariable.dicts("Assigned_Advertisers", months, lowBound=0, cat='Integer')
    W = lp.LpVariable.dicts("Waiting_Pool", months, lowBound=0, cat='Integer')
    D = lp.LpVariable.dicts("Dropped_Advertisers", months, lowBound=0, cat='Integer')
    G = lp.LpVariable.dicts("Graduated_Advertisers", months, lowBound=0, cat='Integer')

    # Initial Conditions
    prob += A[0] == initial_agents

    # Constraints
    W_prev = 0  # Initial waiting pool
    S_prev = 0  # Initial assigned advertisers

    for m in months:
        if m == 0:
            T = A[m]
        else:
            T = A[m] + N[m-1] - F[m-1]

        prob += S[m] <= T * max_adv_per_agent
        prob += W[m] == W_prev + advertiser_data["Advertisers"][m] - S[m] - D[m]
        prob += W[m] >= 0

        if m >= 2:
            prob += D[m] == W[m-2]
            prob += G[m] == S[m-2]
        else:
            prob += D[m] == 0
            prob += G[m] == 0

        prob += N[m] <= A[m]
        prob += F[m] <= A[m]
        prob += T * 10 >= S[m] + S_prev

        if m < n_months - 1:
            prob += A[m+1] == A[m] + N[m] - F[m] + G[m]

        W_prev = W[m]
        S_prev = S[m]

    # Objective Function
    total_cost = lp.lpSum([
        A[m] * monthly_salary + F[m] * firing_cost_perc * annual_salary
        - S[m] * advertiser_data["Avg_Budget"][m] * expected_uplift
        + W[m] * (advertiser_data["Avg_Budget"][m] / 12 * expected_uplift)
        for m in months
    ])
    prob += total_cost

    # Solve the model
    prob.solve()

    # Store results
    results = []
    for m in months:
        results.append({
            "Month": advertiser_data["Month"][m],
            "Available Agents": A[m].varValue,
            "New Hires": N[m].varValue,
            "Fired": F[m].varValue,
            "Assigned Advertisers": S[m].varValue,
            "Waiting Advertisers": W[m].varValue,
            "Dropped Advertisers": D[m].varValue,
            "Graduated Advertisers": G[m].varValue,
            "Total Cost ($)": round(A[m].varValue * monthly_salary + F[m].varValue * firing_cost_perc * annual_salary, 2),
            "Revenue Uplift ($)": round(S[m].varValue * advertiser_data["Avg_Budget"][m] * expected_uplift, 2),
            "Waiting Cost Penalty ($)": round(W[m].varValue * (advertiser_data["Avg_Budget"][m] / 12 * expected_uplift), 2)
        })

    optimization_results[country] = pd.DataFrame(results)

# Concatenate results into one dataframe
final_optimization_df = pd.concat(optimization_results, names=["Country"]).reset_index(level=1, drop=True).reset_index()
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hy/frf0zxvn1k5_c7zh7z63995r0000gn/T/7ca53fa94c3e4a33942c4e46494b9456-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/hy/frf0zxvn1k5_c7zh7z63995r0000gn/T/7ca53fa94c3e4a33942c4e46494b9456-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 113 COLUMNS
# At line 640 RHS
# At line 749 BOUNDS
# At line 834 ENDATA
# Problem MODEL has 108 rows, 84 columns and 310 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 2.52843e+06 - 0.00 seconds
# Cgl0003I 0 fixed, 56 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 56 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 27 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 13 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 4 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 64 rows, 56 columns (56 integer (0 of which binary)) and 234 elements
# Cbc0012I Integer solution of 2577014.5 found by DiveCoefficient after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0038I Full problem 64 rows 56 columns, reduced to 10 rows 6 columns
# Cbc0012I Integer solution of 2557321.8 found by DiveCoefficient after 439 iterations and 0 nodes (0.08 seconds)
# Cbc0031I 5 added rows had average density of 37
# Cbc0013I At root node, 5 cuts changed objective from 2528433.6 to 2537533.8 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 25 column cuts (25 active)  in 0.006 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 572 row cuts average 40.3 elements, 0 column cuts (0 active)  in 0.007 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.005 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.011 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 102 row cuts average 23.2 elements, 0 column cuts (0 active)  in 0.005 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, 2557321.8 best solution, best possible 2537533.8 (0.08 seconds)
# Cbc0012I Integer solution of 2555586.4 found by DiveCoefficient after 471 iterations and 1 nodes (0.08 seconds)
# Cbc0012I Integer solution of 2550198.1 found by DiveCoefficient after 491 iterations and 2 nodes (0.08 seconds)
# Cbc0012I Integer solution of 2546846.5 found by DiveCoefficient after 493 iterations and 3 nodes (0.08 seconds)
# Cbc0016I Integer solution of 2546500.4 found by strong branching after 494 iterations and 3 nodes (0.08 seconds)
# Cbc0012I Integer solution of 2540394.4 found by DiveCoefficient after 497 iterations and 6 nodes (0.08 seconds)
# Cbc0001I Search completed - best objective 2540394.355415941, took 523 iterations and 10 nodes (0.09 seconds)
# Cbc0032I Strong branching done 172 times (257 iterations), fathomed 1 nodes and fixed 2 variables
# Cbc0035I Maximum depth 2, 53 variables fixed on reduced cost
# Cuts at root node changed objective from 2.52843e+06 to 2.53753e+06
# Probing was tried 131 times and created 93 cuts of which 0 were active after adding rounds of cuts (0.007 seconds)
# Gomory was tried 131 times and created 680 cuts of which 0 were active after adding rounds of cuts (0.009 seconds)
# Knapsack was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.005 seconds)
# Clique was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# FlowCover was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.011 seconds)
# TwoMirCuts was tried 100 times and created 102 cuts of which 0 were active after adding rounds of cuts (0.005 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                2540394.35541594
# Enumerated nodes:               10
# Total iterations:               523
# Time (CPU seconds):             0.07
# Time (Wallclock seconds):       0.09
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.07   (Wallclock seconds):       0.09
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hy/frf0zxvn1k5_c7zh7z63995r0000gn/T/d3facd9950924b0fa1260fbe107798eb-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/hy/frf0zxvn1k5_c7zh7z63995r0000gn/T/d3facd9950924b0fa1260fbe107798eb-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 113 COLUMNS
# At line 640 RHS
# At line 749 BOUNDS
# At line 834 ENDATA
# Problem MODEL has 108 rows, 84 columns and 310 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is -1.56026e+06 - 0.00 seconds
# Cgl0003I 0 fixed, 50 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 55 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 30 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 13 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 4 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 64 rows, 56 columns (56 integer (0 of which binary)) and 234 elements
# Cbc0012I Integer solution of -1557602.4 found by DiveCoefficient after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0038I Full problem 64 rows 56 columns, reduced to 4 rows 3 columns
# Cbc0031I 4 added rows had average density of 6.5
# Cbc0013I At root node, 14 cuts changed objective from -1560258.2 to -1557602.4 in 2 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 16 column cuts (16 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 11 row cuts average 7.5 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 28 row cuts average 4.4 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -1557602.435, took 5 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 5 variables fixed on reduced cost
# Cuts at root node changed objective from -1.56026e+06 to -1.5576e+06
# Probing was tried 2 times and created 16 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 2 times and created 11 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 2 times and created 28 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                -1557602.43500000
# Enumerated nodes:               0
# Total iterations:               5
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hy/frf0zxvn1k5_c7zh7z63995r0000gn/T/15a59c2f14c64a39bab9947dd9facda7-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/hy/frf0zxvn1k5_c7zh7z63995r0000gn/T/15a59c2f14c64a39bab9947dd9facda7-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 113 COLUMNS
# At line 640 RHS
# At line 749 BOUNDS
# At line 834 ENDATA
# Problem MODEL has 108 rows, 84 columns and 310 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is -1.58597e+07 - 0.00 seconds
# Cgl0003I 0 fixed, 51 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 55 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 30 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 13 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 4 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 64 rows, 56 columns (56 integer (0 of which binary)) and 234 elements
# Cbc0012I Integer solution of -15847723 found by DiveCoefficient after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0038I Full problem 64 rows 56 columns, reduced to 18 rows 12 columns
# Cbc0031I 5 added rows had average density of 11.6
# Cbc0013I At root node, 5 cuts changed objective from -15859677 to -15850518 in 10 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 19 column cuts (19 active)  in 0.001 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 51 row cuts average 15.6 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 99 row cuts average 13.2 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, -15847723 best solution, best possible -15850518 (0.01 seconds)
# Cbc0012I Integer solution of -15850515 found by DiveCoefficient after 44 iterations and 1 nodes (0.01 seconds)
# Cbc0016I Integer solution of -15850516 found by strong branching after 47 iterations and 1 nodes (0.01 seconds)
# Cbc0001I Search completed - best objective -15850515.86166554, took 51 iterations and 2 nodes (0.01 seconds)
# Cbc0032I Strong branching done 42 times (65 iterations), fathomed 1 nodes and fixed 0 variables
# Cbc0035I Maximum depth 0, 17 variables fixed on reduced cost
# Cuts at root node changed objective from -1.58597e+07 to -1.58505e+07
# Probing was tried 11 times and created 23 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Gomory was tried 11 times and created 51 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 10 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 10 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 10 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 10 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# TwoMirCuts was tried 10 times and created 99 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                -15850515.86166554
# Enumerated nodes:               2
# Total iterations:               51
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hy/frf0zxvn1k5_c7zh7z63995r0000gn/T/b80208aae235403f9a6cf016cf1ee73c-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/hy/frf0zxvn1k5_c7zh7z63995r0000gn/T/b80208aae235403f9a6cf016cf1ee73c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 113 COLUMNS
# At line 640 RHS
# At line 749 BOUNDS
# At line 834 ENDATA
# Problem MODEL has 108 rows, 84 columns and 310 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is -687282 - 0.00 seconds
# Cgl0003I 0 fixed, 45 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 48 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 34 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 12 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 4 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 64 rows, 56 columns (56 integer (0 of which binary)) and 234 elements
# Cbc0012I Integer solution of -677213.4 found by DiveCoefficient after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0038I Full problem 64 rows 56 columns, reduced to 18 rows 11 columns
# Cbc0012I Integer solution of -682479.41 found by DiveCoefficient after 536 iterations and 0 nodes (0.06 seconds)
# Cbc0031I 6 added rows had average density of 34
# Cbc0013I At root node, 6 cuts changed objective from -687282.22 to -684885.55 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 15 column cuts (15 active)  in 0.006 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 460 row cuts average 31.2 elements, 0 column cuts (0 active)  in 0.006 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.005 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.009 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 118 row cuts average 19.4 elements, 0 column cuts (0 active)  in 0.005 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, -682479.41 best solution, best possible -684885.55 (0.06 seconds)
# Cbc0012I Integer solution of -682718.2 found by DiveCoefficient after 545 iterations and 1 nodes (0.06 seconds)
# Cbc0012I Integer solution of -683927.43 found by DiveCoefficient after 552 iterations and 3 nodes (0.06 seconds)
# Cbc0016I Integer solution of -684297.5 found by strong branching after 556 iterations and 3 nodes (0.06 seconds)
# Cbc0001I Search completed - best objective -684297.4995829262, took 602 iterations and 8 nodes (0.06 seconds)
# Cbc0032I Strong branching done 174 times (385 iterations), fathomed 3 nodes and fixed 2 variables
# Cbc0035I Maximum depth 3, 32 variables fixed on reduced cost
# Cuts at root node changed objective from -687282 to -684886
# Probing was tried 114 times and created 43 cuts of which 0 were active after adding rounds of cuts (0.006 seconds)
# Gomory was tried 114 times and created 473 cuts of which 0 were active after adding rounds of cuts (0.006 seconds)
# Knapsack was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.005 seconds)
# Clique was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# FlowCover was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.009 seconds)
# TwoMirCuts was tried 100 times and created 118 cuts of which 0 were active after adding rounds of cuts (0.005 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                -684297.49958293
# Enumerated nodes:               8
# Total iterations:               602
# Time (CPU seconds):             0.06
# Time (Wallclock seconds):       0.07
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.06   (Wallclock seconds):       0.07
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hy/frf0zxvn1k5_c7zh7z63995r0000gn/T/78fe3df4176049edb95d6396453cbfc9-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/hy/frf0zxvn1k5_c7zh7z63995r0000gn/T/78fe3df4176049edb95d6396453cbfc9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 113 COLUMNS
# At line 640 RHS
# At line 749 BOUNDS
# At line 834 ENDATA
# Problem MODEL has 108 rows, 84 columns and 310 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1.21473e+06 - 0.00 seconds
# Cgl0003I 0 fixed, 55 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 55 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 26 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 13 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 4 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 64 rows, 56 columns (56 integer (0 of which binary)) and 234 elements
# Cbc0012I Integer solution of 1216335.8 found by DiveCoefficient after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0038I Full problem 64 rows 56 columns, reduced to 5 rows 4 columns
# Cbc0031I 2 added rows had average density of 10
# Cbc0013I At root node, 33 cuts changed objective from 1214727.8 to 1216335.8 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 11 column cuts (11 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 6 row cuts average 10.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 27 row cuts average 8.7 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 1216335.78750014, took 2 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 3 variables fixed on reduced cost
# Cuts at root node changed objective from 1.21473e+06 to 1.21634e+06
# Probing was tried 1 times and created 11 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 1 times and created 6 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 1 times and created 27 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                1216335.78750014
# Enumerated nodes:               0
# Total iterations:               2
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hy/frf0zxvn1k5_c7zh7z63995r0000gn/T/8e1b3a238f274ccd8e08eefd1d8a9bfd-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/hy/frf0zxvn1k5_c7zh7z63995r0000gn/T/8e1b3a238f274ccd8e08eefd1d8a9bfd-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 113 COLUMNS
# At line 640 RHS
# At line 749 BOUNDS
# At line 834 ENDATA
# Problem MODEL has 108 rows, 84 columns and 310 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 6.35197e+06 - 0.00 seconds
# Cgl0003I 0 fixed, 42 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 51 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 30 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 13 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 4 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 65 rows, 57 columns (57 integer (0 of which binary)) and 236 elements
# Cbc0012I Integer solution of 6357016.1 found by DiveCoefficient after 37 iterations and 0 nodes (0.02 seconds)
# Cbc0031I 4 added rows had average density of 24
# Cbc0013I At root node, 4 cuts changed objective from 6351974.9 to 6357016.1 in 12 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 70 row cuts average 20.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 156 row cuts average 15.2 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 6357016.123332433, took 40 iterations and 0 nodes (0.02 seconds)
# Cbc0032I Strong branching done 8 times (21 iterations), fathomed 1 nodes and fixed 0 variables
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 6.35197e+06 to 6.35702e+06
# Probing was tried 12 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Gomory was tried 12 times and created 70 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Knapsack was tried 12 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 12 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 12 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 12 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# TwoMirCuts was tried 12 times and created 156 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                6357016.12333243
# Enumerated nodes:               0
# Total iterations:               40
# Time (CPU seconds):             0.02
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hy/frf0zxvn1k5_c7zh7z63995r0000gn/T/ddf5447b14294e01b813807059ca9d20-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/hy/frf0zxvn1k5_c7zh7z63995r0000gn/T/ddf5447b14294e01b813807059ca9d20-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 113 COLUMNS
# At line 640 RHS
# At line 749 BOUNDS
# At line 834 ENDATA
# Problem MODEL has 108 rows, 84 columns and 310 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 4.44467e+06 - 0.00 seconds
# Cgl0003I 0 fixed, 57 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 57 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 28 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 13 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 4 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 64 rows, 56 columns (56 integer (0 of which binary)) and 234 elements
# Cbc0012I Integer solution of 4456310.3 found by DiveCoefficient after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0038I Full problem 64 rows 56 columns, reduced to 22 rows 12 columns
# Cbc0031I 6 added rows had average density of 14.833333
# Cbc0013I At root node, 6 cuts changed objective from 4444666.4 to 4452006.1 in 30 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 22 column cuts (22 active)  in 0.001 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 164 row cuts average 17.8 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 134 row cuts average 15.8 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, 4456310.3 best solution, best possible 4452006.1 (0.02 seconds)
# Cbc0012I Integer solution of 4453927.6 found by DiveCoefficient after 70 iterations and 1 nodes (0.02 seconds)
# Cbc0016I Integer solution of 4452006.1 found by strong branching after 71 iterations and 2 nodes (0.02 seconds)
# Cbc0001I Search completed - best objective 4452006.125001481, took 71 iterations and 2 nodes (0.02 seconds)
# Cbc0032I Strong branching done 42 times (69 iterations), fathomed 1 nodes and fixed 1 variables
# Cbc0035I Maximum depth 0, 17 variables fixed on reduced cost
# Cuts at root node changed objective from 4.44467e+06 to 4.45201e+06
# Probing was tried 32 times and created 31 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Gomory was tried 32 times and created 165 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Knapsack was tried 30 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Clique was tried 30 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 30 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 30 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# TwoMirCuts was tried 30 times and created 134 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                4452006.12500148
# Enumerated nodes:               2
# Total iterations:               71
# Time (CPU seconds):             0.02
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hy/frf0zxvn1k5_c7zh7z63995r0000gn/T/3cab14f7dad04d91b007bb41b8e6ba75-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/hy/frf0zxvn1k5_c7zh7z63995r0000gn/T/3cab14f7dad04d91b007bb41b8e6ba75-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 113 COLUMNS
# At line 640 RHS
# At line 749 BOUNDS
# At line 834 ENDATA
# Problem MODEL has 108 rows, 84 columns and 310 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 5.84118e+06 - 0.00 seconds
# Cgl0003I 0 fixed, 56 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 55 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 30 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 13 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 4 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 64 rows, 56 columns (56 integer (0 of which binary)) and 234 elements
# Cbc0012I Integer solution of 5852564.7 found by DiveCoefficient after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0038I Full problem 64 rows 56 columns, reduced to 16 rows 10 columns
# Cbc0031I 6 added rows had average density of 23.666667
# Cbc0013I At root node, 6 cuts changed objective from 5841182 to 5848345 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 36 column cuts (36 active)  in 0.004 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 520 row cuts average 22.3 elements, 0 column cuts (0 active)  in 0.007 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.004 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.009 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 149 row cuts average 15.0 elements, 0 column cuts (0 active)  in 0.005 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, 5852564.7 best solution, best possible 5848345 (0.06 seconds)
# Cbc0001I Search completed - best objective 5852564.711250872, took 860 iterations and 8 nodes (0.06 seconds)
# Cbc0032I Strong branching done 174 times (374 iterations), fathomed 0 nodes and fixed 1 variables
# Cbc0035I Maximum depth 3, 30 variables fixed on reduced cost
# Cuts at root node changed objective from 5.84118e+06 to 5.84835e+06
# Probing was tried 128 times and created 106 cuts of which 0 were active after adding rounds of cuts (0.005 seconds)
# Gomory was tried 128 times and created 628 cuts of which 0 were active after adding rounds of cuts (0.008 seconds)
# Knapsack was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.004 seconds)
# Clique was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# FlowCover was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.009 seconds)
# TwoMirCuts was tried 100 times and created 149 cuts of which 0 were active after adding rounds of cuts (0.005 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                5852564.71125087
# Enumerated nodes:               8
# Total iterations:               860
# Time (CPU seconds):             0.06
# Time (Wallclock seconds):       0.07
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.06   (Wallclock seconds):       0.07
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hy/frf0zxvn1k5_c7zh7z63995r0000gn/T/99623afabe8048da84904cdd0412614f-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/hy/frf0zxvn1k5_c7zh7z63995r0000gn/T/99623afabe8048da84904cdd0412614f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 113 COLUMNS
# At line 640 RHS
# At line 749 BOUNDS
# At line 834 ENDATA
# Problem MODEL has 108 rows, 84 columns and 310 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is -2.2335e+07 - 0.00 seconds
# Cgl0003I 0 fixed, 51 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 52 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 31 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 13 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 4 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 65 rows, 57 columns (57 integer (0 of which binary)) and 236 elements
# Cbc0012I Integer solution of -22329132 found by DiveCoefficient after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0038I Full problem 65 rows 57 columns, reduced to 30 rows 20 columns
# Cbc0031I 4 added rows had average density of 23
# Cbc0013I At root node, 4 cuts changed objective from -22335029 to -22333883 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 15 column cuts (15 active)  in 0.004 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 569 row cuts average 23.0 elements, 0 column cuts (0 active)  in 0.006 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.004 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.008 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 156 row cuts average 18.5 elements, 0 column cuts (0 active)  in 0.005 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, -22329132 best solution, best possible -22333883 (0.05 seconds)
# Cbc0012I Integer solution of -22333307 found by DiveCoefficient after 342 iterations and 2 nodes (0.05 seconds)
# Cbc0012I Integer solution of -22333313 found by DiveCoefficient after 356 iterations and 4 nodes (0.05 seconds)
# Cbc0001I Search completed - best objective -22333313.39958068, took 376 iterations and 6 nodes (0.06 seconds)
# Cbc0032I Strong branching done 152 times (256 iterations), fathomed 1 nodes and fixed 0 variables
# Cbc0035I Maximum depth 2, 14 variables fixed on reduced cost
# Cuts at root node changed objective from -2.2335e+07 to -2.23339e+07
# Probing was tried 116 times and created 38 cuts of which 0 were active after adding rounds of cuts (0.004 seconds)
# Gomory was tried 116 times and created 593 cuts of which 0 were active after adding rounds of cuts (0.007 seconds)
# Knapsack was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.004 seconds)
# Clique was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# FlowCover was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.008 seconds)
# TwoMirCuts was tried 100 times and created 156 cuts of which 0 were active after adding rounds of cuts (0.005 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                -22333313.39958068
# Enumerated nodes:               6
# Total iterations:               376
# Time (CPU seconds):             0.05
# Time (Wallclock seconds):       0.06
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.06   (Wallclock seconds):       0.06
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hy/frf0zxvn1k5_c7zh7z63995r0000gn/T/47d44dab8d114512800ee0dbdc435deb-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/hy/frf0zxvn1k5_c7zh7z63995r0000gn/T/47d44dab8d114512800ee0dbdc435deb-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 113 COLUMNS
# At line 640 RHS
# At line 749 BOUNDS
# At line 834 ENDATA
# Problem MODEL has 108 rows, 84 columns and 310 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 2.29881e+06 - 0.00 seconds
# Cgl0003I 0 fixed, 45 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 48 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 30 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 13 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 4 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 64 rows, 56 columns (56 integer (0 of which binary)) and 234 elements
# Cbc0012I Integer solution of 2305112 found by DiveCoefficient after 16 iterations and 0 nodes (0.01 seconds)
# Cbc0031I 6 added rows had average density of 17
# Cbc0013I At root node, 6 cuts changed objective from 2298807.4 to 2305112 in 5 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 34 row cuts average 28.9 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 71 row cuts average 21.2 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 2305112.0075006, took 16 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 2.29881e+06 to 2.30511e+06
# Probing was tried 5 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 5 times and created 34 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 5 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 5 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 5 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 5 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 5 times and created 71 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                2305112.00750060
# Enumerated nodes:               0
# Total iterations:               16
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hy/frf0zxvn1k5_c7zh7z63995r0000gn/T/45434bfc23fb414d9d2042421709233e-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/hy/frf0zxvn1k5_c7zh7z63995r0000gn/T/45434bfc23fb414d9d2042421709233e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 113 COLUMNS
# At line 640 RHS
# At line 749 BOUNDS
# At line 834 ENDATA
# Problem MODEL has 108 rows, 84 columns and 310 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1.15072e+07 - 0.00 seconds
# Cgl0003I 0 fixed, 51 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 55 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 26 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 13 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 4 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 64 rows, 56 columns (56 integer (0 of which binary)) and 234 elements
# Cbc0012I Integer solution of 11536073 found by DiveCoefficient after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0038I Full problem 64 rows 56 columns, reduced to 18 rows 10 columns
# Cbc0012I Integer solution of 11519242 found by DiveCoefficient after 10 iterations and 0 nodes (0.01 seconds)
# Cbc0031I 4 added rows had average density of 9
# Cbc0013I At root node, 4 cuts changed objective from 11507246 to 11519242 in 5 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 13 column cuts (13 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 20 row cuts average 13.7 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 38 row cuts average 11.3 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 11519242.44375, took 10 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 12 variables fixed on reduced cost
# Cuts at root node changed objective from 1.15072e+07 to 1.15192e+07
# Probing was tried 5 times and created 13 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 5 times and created 20 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 5 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 5 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 5 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 5 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 5 times and created 38 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                11519242.44375000
# Enumerated nodes:               0
# Total iterations:               10
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/pulp.py:1298: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")
# ...
# Cbc0032I Strong branching done 64 times (134 iterations), fathomed 0 nodes and fixed 3 variables
# Cbc0035I Maximum depth 1, 17 variables fixed on reduced cost
# Cuts at root node changed objective from 1.22007e+06 to 1.22529e+06
# Probing was tried 108 times and created 63 cuts of which 0 were active after adding rounds of cuts (0.004 seconds)
# Gomory was tried 108 times and created 504 cuts of which 0 were active after adding rounds of cuts (0.007 seconds)
# Knapsack was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# Clique was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# FlowCover was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.009 seconds)
# TwoMirCuts was tried 100 times and created 139 cuts of which 0 were active after adding rounds of cuts (0.005 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                1225539.45041682
# Enumerated nodes:               4
# Total iterations:               597
# Time (CPU seconds):             0.05
# Time (Wallclock seconds):       0.06
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.05   (Wallclock seconds):       0.06
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hy/frf0zxvn1k5_c7zh7z63995r0000gn/T/04c558b117c44bd4b12d66dae347e116-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/hy/frf0zxvn1k5_c7zh7z63995r0000gn/T/04c558b117c44bd4b12d66dae347e116-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 113 COLUMNS
# At line 640 RHS
# At line 749 BOUNDS
# At line 834 ENDATA
# Problem MODEL has 108 rows, 84 columns and 310 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is -3.73244e+07 - 0.00 seconds
# Cgl0003I 0 fixed, 49 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 52 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 31 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 13 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 4 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 64 rows, 56 columns (56 integer (0 of which binary)) and 234 elements
# Cbc0012I Integer solution of -37319004 found by DiveCoefficient after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0038I Full problem 64 rows 56 columns, reduced to 28 rows 17 columns
# Cbc0012I Integer solution of -37321138 found by DiveCoefficient after 285 iterations and 0 nodes (0.04 seconds)
# Cbc0031I 6 added rows had average density of 28
# Cbc0013I At root node, 6 cuts changed objective from -37324369 to -37322092 in 74 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 18 column cuts (18 active)  in 0.003 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 310 row cuts average 29.2 elements, 0 column cuts (0 active)  in 0.005 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.004 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.006 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 154 row cuts average 17.0 elements, 0 column cuts (0 active)  in 0.004 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, -37321138 best solution, best possible -37322092 (0.04 seconds)
# Cbc0012I Integer solution of -37321684 found by DiveCoefficient after 286 iterations and 1 nodes (0.04 seconds)
# Cbc0012I Integer solution of -37321947 found by DiveCoefficient after 292 iterations and 2 nodes (0.04 seconds)
# Cbc0001I Search completed - best objective -37321947.1025, took 335 iterations and 6 nodes (0.04 seconds)
# Cbc0032I Strong branching done 138 times (230 iterations), fathomed 3 nodes and fixed 1 variables
# Cbc0035I Maximum depth 2, 21 variables fixed on reduced cost
# Cuts at root node changed objective from -3.73244e+07 to -3.73221e+07
# Probing was tried 83 times and created 51 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# Gomory was tried 83 times and created 312 cuts of which 0 were active after adding rounds of cuts (0.005 seconds)
# Knapsack was tried 74 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.004 seconds)
# Clique was tried 74 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 74 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# FlowCover was tried 74 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.006 seconds)
# TwoMirCuts was tried 74 times and created 154 cuts of which 0 were active after adding rounds of cuts (0.004 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                -37321947.10250000
# Enumerated nodes:               6
# Total iterations:               335
# Time (CPU seconds):             0.04
# Time (Wallclock seconds):       0.05
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.04   (Wallclock seconds):       0.05
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/pulp.py:1298: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hy/frf0zxvn1k5_c7zh7z63995r0000gn/T/125a9d2d11bd404e8bda1e15d84c887e-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/hy/frf0zxvn1k5_c7zh7z63995r0000gn/T/125a9d2d11bd404e8bda1e15d84c887e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 113 COLUMNS
# At line 640 RHS
# At line 749 BOUNDS
# At line 834 ENDATA
# Problem MODEL has 108 rows, 84 columns and 310 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is -6.05697e+06 - 0.00 seconds
# Cgl0003I 0 fixed, 51 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 54 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 31 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 13 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 4 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 64 rows, 56 columns (56 integer (0 of which binary)) and 234 elements
# Cbc0012I Integer solution of -6008684.9 found by DiveCoefficient after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0038I Full problem 64 rows 56 columns, reduced to 18 rows 10 columns
# Cbc0012I Integer solution of -6029808.5 found by DiveCoefficient after 467 iterations and 0 nodes (0.05 seconds)
# Cbc0031I 6 added rows had average density of 26
# Cbc0013I At root node, 6 cuts changed objective from -6056969.1 to -6044424.4 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 82 column cuts (82 active)  in 0.005 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 636 row cuts average 25.2 elements, 0 column cuts (0 active)  in 0.006 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.005 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.009 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 116 row cuts average 19.2 elements, 0 column cuts (0 active)  in 0.004 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, -6029808.5 best solution, best possible -6044424.4 (0.05 seconds)
# Cbc0012I Integer solution of -6033296.5 found by DiveCoefficient after 501 iterations and 2 nodes (0.06 seconds)
# Cbc0016I Integer solution of -6033694.6 found by strong branching after 542 iterations and 3 nodes (0.06 seconds)
# Cbc0012I Integer solution of -6035887.2 found by DiveCoefficient after 544 iterations and 4 nodes (0.06 seconds)
# Cbc0016I Integer solution of -6038477.9 found by strong branching after 564 iterations and 5 nodes (0.06 seconds)
# Cbc0001I Search completed - best objective -6038477.93875, took 669 iterations and 10 nodes (0.07 seconds)
# Cbc0032I Strong branching done 202 times (327 iterations), fathomed 3 nodes and fixed 3 variables
# Cbc0035I Maximum depth 3, 53 variables fixed on reduced cost
# Cuts at root node changed objective from -6.05697e+06 to -6.04442e+06
# Probing was tried 154 times and created 190 cuts of which 0 were active after adding rounds of cuts (0.007 seconds)
# Gomory was tried 154 times and created 778 cuts of which 0 were active after adding rounds of cuts (0.007 seconds)
# Knapsack was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.005 seconds)
# Clique was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# FlowCover was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.009 seconds)
# TwoMirCuts was tried 100 times and created 116 cuts of which 0 were active after adding rounds of cuts (0.004 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                -6038477.93875000
# Enumerated nodes:               10
# Total iterations:               669
# Time (CPU seconds):             0.07
# Time (Wallclock seconds):       0.07
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.07   (Wallclock seconds):       0.07
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hy/frf0zxvn1k5_c7zh7z63995r0000gn/T/bb9e23fa75934080af439a659cbc245c-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/hy/frf0zxvn1k5_c7zh7z63995r0000gn/T/bb9e23fa75934080af439a659cbc245c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 113 COLUMNS
# At line 640 RHS
# At line 749 BOUNDS
# At line 834 ENDATA
# Problem MODEL has 108 rows, 84 columns and 310 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1.93716e+06 - 0.00 seconds
# Cgl0003I 0 fixed, 49 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 52 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 31 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 13 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 4 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 64 rows, 56 columns (56 integer (0 of which binary)) and 234 elements
# Cbc0012I Integer solution of 1951261.6 found by DiveCoefficient after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0038I Full problem 64 rows 56 columns, reduced to 19 rows 11 columns
# Cbc0012I Integer solution of 1946815.2 found by DiveCoefficient after 504 iterations and 0 nodes (0.07 seconds)
# Cbc0031I 8 added rows had average density of 25.875
# Cbc0013I At root node, 8 cuts changed objective from 1937161.3 to 1944215 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 19 column cuts (19 active)  in 0.005 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 738 row cuts average 31.5 elements, 0 column cuts (0 active)  in 0.006 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.005 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.009 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 116 row cuts average 22.3 elements, 0 column cuts (0 active)  in 0.005 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, 1946815.2 best solution, best possible 1944215 (0.07 seconds)
# Cbc0012I Integer solution of 1945271.7 found by DiveCoefficient after 510 iterations and 1 nodes (0.07 seconds)
# Cbc0012I Integer solution of 1944484.8 found by DiveCoefficient after 516 iterations and 3 nodes (0.07 seconds)
# Cbc0016I Integer solution of 1944386.3 found by strong branching after 520 iterations and 4 nodes (0.07 seconds)
# Cbc0001I Search completed - best objective 1944386.292083204, took 573 iterations and 10 nodes (0.08 seconds)
# Cbc0032I Strong branching done 168 times (386 iterations), fathomed 3 nodes and fixed 5 variables
# Cbc0035I Maximum depth 4, 36 variables fixed on reduced cost
# Cuts at root node changed objective from 1.93716e+06 to 1.94422e+06
# Probing was tried 113 times and created 54 cuts of which 0 were active after adding rounds of cuts (0.006 seconds)
# Gomory was tried 113 times and created 744 cuts of which 0 were active after adding rounds of cuts (0.006 seconds)
# Knapsack was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.005 seconds)
# Clique was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# FlowCover was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.009 seconds)
# TwoMirCuts was tried 100 times and created 116 cuts of which 0 were active after adding rounds of cuts (0.005 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                1944386.29208320
# Enumerated nodes:               10
# Total iterations:               573
# Time (CPU seconds):             0.07
# Time (Wallclock seconds):       0.08
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.07   (Wallclock seconds):       0.08

# %%
final_optimization_df
# Out:
#       Country    Month  Available Agents  New Hires  Fired  \
# 0      Canada  2025-01             228.0        0.0  113.0
# 1      Canada  2025-02             115.0        0.0   56.0
# 2      Canada  2025-03              59.0        0.0   29.0
# 3      Canada  2025-04              30.0        0.0    2.0
# 4      Canada  2025-05              41.0        0.0    0.0
# ..        ...      ...               ...        ...    ...
# 259  Thailand  2025-08               8.0        0.0    0.0
# 260  Thailand  2025-09               8.0        3.0    0.0
# 261  Thailand  2025-10              11.0        0.0    0.0
# 262  Thailand  2025-11              11.0        0.0    0.0
# 263  Thailand  2025-12              46.0        0.0    0.0
#
#      Assigned Advertisers  Waiting Advertisers  Dropped Advertisers  \
# 0                     0.0                371.0                  0.0
# 1                    13.0                703.0                  0.0
# 2                     8.0                678.0                371.0
# 3                     0.0                332.0                703.0
# 4                     0.0                 24.0                678.0
# ..                    ...                  ...                  ...
# 259                   0.0                155.0                  4.0
# 260                  35.0                137.0                 88.0
# 261                 105.0                  2.0                155.0
# 262                   0.0                  0.0                137.0
# 263                 122.0                  0.0                  2.0
#
#      Graduated Advertisers  Total Cost ($)  Revenue Uplift ($)  \
# 0                      0.0      3920052.00                0.00
# 1                      0.0      1952902.33            80436.92
# 2                      0.0      1008507.67            52294.68
# 3                     13.0       201498.00                0.00
# 4                      8.0       208621.67                0.00
# ..                     ...             ...                 ...
# 259                    0.0        16192.67                0.00
# 260                    0.0        16192.67            44599.28
# 261                    0.0        22264.92           159950.70
# 262                   35.0        22264.92                0.00
# 263                  105.0        93107.83           151820.46
#
#      Waiting Cost Penalty ($)
# 0                   188682.72
# 1                   362481.74
# 2                   369331.18
# 3                   170442.99
# 4                    12271.77
# ..                        ...
# 259                  14966.61
# 260                  14547.86
# 261                    253.89
# 262                      0.00
# 263                      0.00
#
# [264 rows x 12 columns]

# %%
# Define the file path
output_csv_path = "Optimized_Staffing_Results.csv"

# Export the DataFrame to CSV
final_optimization_df.to_csv(output_csv_path, index=False)

print(f"File saved as {output_csv_path}")
# Out:
# File saved as Optimized_Staffing_Results.csv

# %%
# Store results for all countries
optimization_results = {}

# Load the processed data from CSV
final_df = pd.read_csv("Final_Processed_Data.csv")

# Iterate through each country
for country in final_df["Country"].unique():
    # Filter data for the specific country
    country_df = final_df[final_df["Country"] == country]

    # Extract parameters
    advertiser_data = country_df[["Month", "Advertisers", "Avg_Budget"]].reset_index(drop=True)
    initial_agents = country_df["Existing_Agent_Count"].iloc[0]
    annual_salary = country_df["Annual_Agent_Salary_USD"].iloc[0]
    monthly_salary = annual_salary / 12

    # Constants
    firing_cost_perc = 0.4
    max_adv_per_agent = 10
    expected_uplift = 0.135
    n_months = len(advertiser_data)

    # Initialize PuLP problem
    prob = lp.LpProblem(f"Dynamic_Staffing_Optimization_{country}", lp.LpMinimize)

    # Decision Variables
    months = list(range(n_months))
    A = lp.LpVariable.dicts("Available_Agents", months, lowBound=0, cat='Integer')
    N = lp.LpVariable.dicts("New_Hires", months, lowBound=0, cat='Integer')
    F = lp.LpVariable.dicts("Fired", months, lowBound=0, cat='Integer')
    S = lp.LpVariable.dicts("Assigned_Advertisers", months, lowBound=0, cat='Integer')
    W = lp.LpVariable.dicts("Waiting_Pool", months, lowBound=0, cat='Integer')
    D = lp.LpVariable.dicts("Dropped_Advertisers", months, lowBound=0, cat='Integer')
    G = lp.LpVariable.dicts("Graduated_Advertisers", months, lowBound=0, cat='Integer')
    T = lp.LpVariable.dicts("Total_Agents", months, lowBound=0, cat='Integer')  # Total Agents in month (need to pay salary)

    # Initial Conditions
    prob += A[0] == initial_agents  # Starting agents
    W_prev = 0  # Initial waiting pool
    S_prev = 0  # Initial assigned advertisers

    # Constraints
    for m in months:

        # 1. Waiting Pool: W[m] = W_prev + new advertisers - assigned - dropped
        prob += W[m] == W_prev + advertiser_data['Advertisers'][m] - S[m] - D[m]
        prob += W[m] >= 0

        # 2. Dropped Advertisers: Those waiting for more than 60 days
        if m >= 2:
            prob += D[m] == W[m-2]  # Drop advertisers who have been waiting for 2 months
        else:
            prob += D[m] == 0  # No one is dropped in the first two months

        # 3. Graduated Advertisers: Advertisers exit after 60 days of support
        if m >= 2:
            prob += G[m] == S[m-2]  # Graduates advertisers assigned two months ago
        else:
            prob += G[m] == 0  # No one graduates in the first two months

        # 4. Hiring/Firing Constraints
        prob += N[m] <= A[m]
        prob += F[m] <= A[m]

        # 5. Required Agents: A[m] * 10 >= S[m] + S_prev (eliminates division)
        prob += A[m] * 10 >= S[m] + S_prev  # Ensures sufficient capacity for current and past advertisers

        # Update next month's available agents
        if m < n_months - 1:
            prob += A[m+1] == A[m] + N[m] - F[m]

        # Update variables for next iteration
        W_prev = W[m]
        S_prev = S[m]

        # Update Total Agents (Can support advertisers + cannot support advertisers)
        if m == 0:
            prob += T[m] == A[m] + N[m]
        else:
            prob += T[m] == T[m-1] + N[m] - F[m-1]

    # Objective Function (Minimize Costs + Waiting Time Penalty)
    total_cost = lp.lpSum(
        [A[m] * monthly_salary + F[m] * firing_cost_perc * annual_salary
        - S[m] * advertiser_data['Avg_Budget'][m] * expected_uplift
        + W[m] * (advertiser_data['Avg_Budget'][m] / 12 * expected_uplift)  # Waiting penalty
        for m in months]
    )
    prob += total_cost

    # Solve
    prob.solve()

    # Store results
    results = []

    for m in months:
        results.append({
            'Month': advertiser_data['Month'][m],
            'Available Agents': A[m].varValue,
            'New Hires': N[m].varValue,
            'Fired': F[m].varValue,
            'Total Agents':T[m].varValue,
            'Assigned Advertisers': S[m].varValue,
            'Waiting Advertisers': W[m].varValue,
            'Dropped Advertisers': D[m].varValue,
            'Graduated Advertisers': G[m].varValue,
            'Total Cost ($)': round(T[m].varValue * monthly_salary + F[m].varValue * firing_cost_perc * annual_salary, 2),
            'Revenue Uplift ($)': round(S[m].varValue * advertiser_data['Avg_Budget'][m] * expected_uplift, 2),
            'Waiting Cost Penalty ($)': round(W[m].varValue * (advertiser_data['Avg_Budget'][m] / 12 * expected_uplift), 2),
            "Net Profit ($)": (round(S[m].varValue * advertiser_data["Avg_Budget"][m] * expected_uplift, 2)) - (round(T[m].varValue * monthly_salary + F[m].varValue * firing_cost_perc * annual_salary, 2))   # New column added
    })

    optimization_results[country] = pd.DataFrame(results)

# Concatenate results into one dataframe
final_optimization_df = pd.concat(optimization_results, names=["Country"]).reset_index(level=1, drop=True).reset_index()
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hy/frf0zxvn1k5_c7zh7z63995r0000gn/T/d8c0e9c1891447e784117db35720e930-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/hy/frf0zxvn1k5_c7zh7z63995r0000gn/T/d8c0e9c1891447e784117db35720e930-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 113 COLUMNS
# At line 632 RHS
# At line 741 BOUNDS
# At line 838 ENDATA
# Problem MODEL has 108 rows, 96 columns and 278 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is -2.02184e+07 - 0.00 seconds
# Cgl0003I 0 fixed, 20 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 16 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 12 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 8 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 4 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 64 rows, 66 columns (66 integer (0 of which binary)) and 202 elements
# Cbc0012I Integer solution of -20211916 found by DiveCoefficient after 0 iterations and 0 nodes (0.02 seconds)
# Cbc0038I Full problem 64 rows 66 columns, reduced to 1 rows 2 columns
# Cbc0006I The LP relaxation is infeasible or too expensive
# Cbc0013I At root node, 0 cuts changed objective from -20218423 to -20211916 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 6 row cuts average 2.5 elements, 5 column cuts (5 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -20211915.5283337, took 5 iterations and 0 nodes (0.03 seconds)
# Cbc0035I Maximum depth 0, 7 variables fixed on reduced cost
# Cuts at root node changed objective from -2.02184e+07 to -2.02119e+07
# Probing was tried 1 times and created 11 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                -20211915.52833370
# Enumerated nodes:               0
# Total iterations:               5
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.03
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.03
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hy/frf0zxvn1k5_c7zh7z63995r0000gn/T/5920470fd0eb474c809348f923c69adf-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/hy/frf0zxvn1k5_c7zh7z63995r0000gn/T/5920470fd0eb474c809348f923c69adf-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 113 COLUMNS
# At line 632 RHS
# At line 741 BOUNDS
# At line 838 ENDATA
# Problem MODEL has 108 rows, 96 columns and 278 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is -9.91072e+06 - 0.00 seconds
# Cgl0003I 0 fixed, 20 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 16 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 12 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 8 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 4 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 64 rows, 66 columns (66 integer (0 of which binary)) and 202 elements
# Cbc0012I Integer solution of -9859417.4 found by DiveCoefficient after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0038I Full problem 64 rows 66 columns, reduced to 13 rows 13 columns
# Cbc0012I Integer solution of -9902642.1 found by DiveCoefficient after 8 iterations and 0 nodes (0.02 seconds)
# Cbc0031I 6 added rows had average density of 4.6666667
# Cbc0013I At root node, 6 cuts changed objective from -9910718.9 to -9902642.1 in 3 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 6 column cuts (6 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 12 row cuts average 7.7 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 24 row cuts average 7.1 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 1 row cuts average 2.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -9902642.077500001, took 8 iterations and 0 nodes (0.02 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -9.91072e+06 to -9.90264e+06
# Probing was tried 3 times and created 6 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 3 times and created 12 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 3 times and created 24 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 1 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                -9902642.07750000
# Enumerated nodes:               0
# Total iterations:               8
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hy/frf0zxvn1k5_c7zh7z63995r0000gn/T/de6c3149590d4f08bb918aead0bce24b-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/hy/frf0zxvn1k5_c7zh7z63995r0000gn/T/de6c3149590d4f08bb918aead0bce24b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 113 COLUMNS
# At line 632 RHS
# At line 741 BOUNDS
# At line 838 ENDATA
# Problem MODEL has 108 rows, 96 columns and 278 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is -4.47545e+07 - 0.00 seconds
# Cgl0003I 0 fixed, 20 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 16 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 12 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 8 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 4 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 64 rows, 66 columns (66 integer (0 of which binary)) and 202 elements
# Cbc0012I Integer solution of -44736630 found by DiveCoefficient after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0038I Full problem 64 rows 66 columns, reduced to 2 rows 3 columns
# Cbc0012I Integer solution of -44747810 found by DiveCoefficient after 3 iterations and 0 nodes (0.01 seconds)
# Cbc0031I 1 added rows had average density of 5
# Cbc0013I At root node, 1 cuts changed objective from -44754472 to -44747810 in 5 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 9 column cuts (9 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 1 row cuts average 5.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 17 row cuts average 7.2 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -44747810.41666623, took 3 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -4.47545e+07 to -4.47478e+07
# Probing was tried 5 times and created 9 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 5 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 5 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 5 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 5 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 5 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 5 times and created 17 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                -44747810.41666623
# Enumerated nodes:               0
# Total iterations:               3
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hy/frf0zxvn1k5_c7zh7z63995r0000gn/T/6fa0126587254458bd96dd436af2e94c-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/hy/frf0zxvn1k5_c7zh7z63995r0000gn/T/6fa0126587254458bd96dd436af2e94c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 113 COLUMNS
# At line 632 RHS
# At line 741 BOUNDS
# At line 838 ENDATA
# Problem MODEL has 108 rows, 96 columns and 278 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is -4.38032e+06 - 0.00 seconds
# Cgl0003I 0 fixed, 20 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 16 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 12 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 8 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 4 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 64 rows, 66 columns (66 integer (0 of which binary)) and 202 elements
# Cbc0012I Integer solution of -4344429.4 found by DiveCoefficient after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0038I Full problem 64 rows 66 columns, reduced to 8 rows 8 columns
# Cbc0012I Integer solution of -4379293.1 found by DiveCoefficient after 3 iterations and 0 nodes (0.01 seconds)
# Cbc0031I 2 added rows had average density of 5
# Cbc0013I At root node, 2 cuts changed objective from -4380321.5 to -4379293.1 in 3 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 6 column cuts (6 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 4 row cuts average 7.2 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 8 row cuts average 5.6 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -4379293.133749843, took 3 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -4.38032e+06 to -4.37929e+06
# Probing was tried 3 times and created 6 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 3 times and created 4 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 3 times and created 8 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                -4379293.13374984
# Enumerated nodes:               0
# Total iterations:               3
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hy/frf0zxvn1k5_c7zh7z63995r0000gn/T/c671ab044e464c7e84f815c00d07d1bb-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/hy/frf0zxvn1k5_c7zh7z63995r0000gn/T/c671ab044e464c7e84f815c00d07d1bb-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 113 COLUMNS
# At line 632 RHS
# At line 741 BOUNDS
# At line 838 ENDATA
# Problem MODEL has 108 rows, 96 columns and 278 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is -1.95739e+06 - 0.00 seconds
# Cgl0003I 0 fixed, 20 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 16 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 12 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 8 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 4 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 64 rows, 66 columns (66 integer (0 of which binary)) and 202 elements
# Cbc0012I Integer solution of -1950534.8 found by DiveCoefficient after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0038I Full problem 64 rows 66 columns, reduced to 0 rows 0 columns
# Cbc0012I Integer solution of -1951621.3 found by DiveCoefficient after 5 iterations and 0 nodes (0.01 seconds)
# Cbc0031I 3 added rows had average density of 5
# Cbc0013I At root node, 3 cuts changed objective from -1957394.4 to -1951621.3 in 4 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 7 column cuts (7 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 5 row cuts average 7.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 23 row cuts average 5.4 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -1951621.29083317, took 5 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 7 variables fixed on reduced cost
# Cuts at root node changed objective from -1.95739e+06 to -1.95162e+06
# Probing was tried 4 times and created 7 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 4 times and created 5 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 4 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 4 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 4 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 4 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 4 times and created 23 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                -1951621.29083317
# Enumerated nodes:               0
# Total iterations:               5
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hy/frf0zxvn1k5_c7zh7z63995r0000gn/T/da2ada1d0c3e44a2a8e2adf200e409ed-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/hy/frf0zxvn1k5_c7zh7z63995r0000gn/T/da2ada1d0c3e44a2a8e2adf200e409ed-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 113 COLUMNS
# At line 632 RHS
# At line 741 BOUNDS
# At line 838 ENDATA
# Problem MODEL has 108 rows, 96 columns and 278 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is -1.14592e+07 - 0.00 seconds
# Cgl0003I 0 fixed, 20 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 16 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 12 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 8 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 4 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 65 rows, 67 columns (67 integer (0 of which binary)) and 204 elements
# Cbc0012I Integer solution of -11445399 found by DiveCoefficient after 6 iterations and 0 nodes (0.01 seconds)
# Cbc0031I 6 added rows had average density of 4.6666667
# Cbc0013I At root node, 6 cuts changed objective from -11459202 to -11445399 in 2 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 11 row cuts average 6.5 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 26 row cuts average 5.7 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 1 row cuts average 3.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -11445399.29208376, took 6 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -1.14592e+07 to -1.14454e+07
# Probing was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 2 times and created 11 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 2 times and created 26 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 1 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                -11445399.29208376
# Enumerated nodes:               0
# Total iterations:               6
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hy/frf0zxvn1k5_c7zh7z63995r0000gn/T/f490a4a5b7044c42a9d820dcda22b420-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/hy/frf0zxvn1k5_c7zh7z63995r0000gn/T/f490a4a5b7044c42a9d820dcda22b420-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 113 COLUMNS
# At line 632 RHS
# At line 741 BOUNDS
# At line 838 ENDATA
# Problem MODEL has 108 rows, 96 columns and 278 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is -3.38318e+07 - 0.00 seconds
# Cgl0003I 0 fixed, 20 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 16 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 12 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 8 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 4 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 64 rows, 66 columns (66 integer (0 of which binary)) and 202 elements
# Cbc0012I Integer solution of -33815912 found by DiveCoefficient after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0038I Full problem 64 rows 66 columns, reduced to 12 rows 12 columns
# Cbc0012I Integer solution of -33820216 found by DiveCoefficient after 7 iterations and 0 nodes (0.01 seconds)
# Cbc0031I 2 added rows had average density of 4.5
# Cbc0013I At root node, 2 cuts changed objective from -33831752 to -33820216 in 4 passes
# Cbc0014I Cut generator 0 (Probing) - 4 row cuts average 3.0 elements, 14 column cuts (14 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 3 row cuts average 4.7 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 13 row cuts average 3.5 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 1 row cuts average 2.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -33820216.33333275, took 7 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 17 variables fixed on reduced cost
# Cuts at root node changed objective from -3.38318e+07 to -3.38202e+07
# Probing was tried 4 times and created 18 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 4 times and created 3 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 4 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 4 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 4 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 4 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 4 times and created 13 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 1 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                -33820216.33333275
# Enumerated nodes:               0
# Total iterations:               7
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hy/frf0zxvn1k5_c7zh7z63995r0000gn/T/84025df9550b4d50bc20ed61ac7d32e0-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/hy/frf0zxvn1k5_c7zh7z63995r0000gn/T/84025df9550b4d50bc20ed61ac7d32e0-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 113 COLUMNS
# At line 632 RHS
# At line 741 BOUNDS
# At line 838 ENDATA
# Problem MODEL has 108 rows, 96 columns and 278 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is -1.2857e+07 - 0.00 seconds
# Cgl0003I 0 fixed, 20 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 16 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 12 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 8 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 4 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 64 rows, 66 columns (66 integer (0 of which binary)) and 202 elements
# Cbc0012I Integer solution of -12815817 found by DiveCoefficient after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0038I Full problem 64 rows 66 columns, reduced to 7 rows 7 columns
# Cbc0012I Integer solution of -12848446 found by DiveCoefficient after 4 iterations and 0 nodes (0.01 seconds)
# Cbc0031I 3 added rows had average density of 5
# Cbc0013I At root node, 3 cuts changed objective from -12856978 to -12848446 in 3 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 8 column cuts (8 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 5 row cuts average 7.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 23 row cuts average 6.7 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -12848445.56458289, took 4 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -1.2857e+07 to -1.28484e+07
# Probing was tried 3 times and created 8 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 3 times and created 5 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 3 times and created 23 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                -12848445.56458289
# Enumerated nodes:               0
# Total iterations:               4
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hy/frf0zxvn1k5_c7zh7z63995r0000gn/T/a0dbde93fca9453fb2f5ba3719aa3ce4-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/hy/frf0zxvn1k5_c7zh7z63995r0000gn/T/a0dbde93fca9453fb2f5ba3719aa3ce4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 113 COLUMNS
# At line 632 RHS
# At line 741 BOUNDS
# At line 838 ENDATA
# Problem MODEL has 108 rows, 96 columns and 278 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is -5.23924e+07 - 0.00 seconds
# Cgl0003I 0 fixed, 20 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 16 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 12 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 8 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 4 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 65 rows, 67 columns (67 integer (0 of which binary)) and 204 elements
# Cbc0012I Integer solution of -52389026 found by DiveCoefficient after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0038I Full problem 65 rows 67 columns, reduced to 5 rows 5 columns
# Cbc0031I 1 added rows had average density of 3
# Cbc0013I At root node, 8 cuts changed objective from -52392440 to -52389026 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 1 row cuts average 2.0 elements, 4 column cuts (4 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 1 row cuts average 3.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 6 row cuts average 2.5 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -52389026.39833289, took 6 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 1 variables fixed on reduced cost
# Cuts at root node changed objective from -5.23924e+07 to -5.2389e+07
# Probing was tried 1 times and created 5 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 1 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 1 times and created 6 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                -52389026.39833289
# Enumerated nodes:               0
# Total iterations:               6
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hy/frf0zxvn1k5_c7zh7z63995r0000gn/T/45814f230da84b3daacad43efba1bb9c-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/hy/frf0zxvn1k5_c7zh7z63995r0000gn/T/45814f230da84b3daacad43efba1bb9c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 113 COLUMNS
# At line 632 RHS
# At line 741 BOUNDS
# At line 838 ENDATA
# Problem MODEL has 108 rows, 96 columns and 278 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is -9.23832e+06 - 0.00 seconds
# Cgl0003I 0 fixed, 20 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 16 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 12 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 8 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 4 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 64 rows, 66 columns (66 integer (0 of which binary)) and 202 elements
# Cbc0012I Integer solution of -9224847.2 found by DiveCoefficient after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0038I Full problem 64 rows 66 columns, reduced to 6 rows 6 columns
# Cbc0012I Integer solution of -9233299.6 found by DiveCoefficient after 5 iterations and 0 nodes (0.01 seconds)
# Cbc0031I 3 added rows had average density of 5
# Cbc0013I At root node, 3 cuts changed objective from -9238316.2 to -9233299.6 in 3 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 7 column cuts (7 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 7 row cuts average 7.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 25 row cuts average 5.7 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -9233299.649999697, took 5 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 7 variables fixed on reduced cost
# Cuts at root node changed objective from -9.23832e+06 to -9.2333e+06
# Probing was tried 3 times and created 7 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 3 times and created 7 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 3 times and created 25 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                -9233299.64999970
# Enumerated nodes:               0
# Total iterations:               5
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hy/frf0zxvn1k5_c7zh7z63995r0000gn/T/73840913c465466fbb9e0c40f2c24e9b-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/hy/frf0zxvn1k5_c7zh7z63995r0000gn/T/73840913c465466fbb9e0c40f2c24e9b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 113 COLUMNS
# At line 632 RHS
# At line 741 BOUNDS
# At line 838 ENDATA
# Problem MODEL has 108 rows, 96 columns and 278 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 9.77325e+06 - 0.00 seconds
# Cgl0003I 0 fixed, 20 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 16 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 12 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 8 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 4 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 64 rows, 66 columns (66 integer (0 of which binary)) and 202 elements
# Cbc0012I Integer solution of 9777508.1 found by DiveCoefficient after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0038I Full problem 64 rows 66 columns, reduced to 6 rows 8 columns
# Cbc0012I Integer solution of 9774421.4 found by DiveCoefficient after 18 iterations and 0 nodes (0.01 seconds)
# Cbc0031I 3 added rows had average density of 10.333333
# Cbc0013I At root node, 3 cuts changed objective from 9773254.9 to 9774421.4 in 5 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 16 column cuts (16 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 8 row cuts average 11.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 69 row cuts average 9.3 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 9774421.443750001, took 18 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 3 variables fixed on reduced cost
# Cuts at root node changed objective from 9.77325e+06 to 9.77442e+06
# Probing was tried 5 times and created 16 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 5 times and created 8 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 5 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 5 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 5 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 5 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 5 times and created 69 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                9774421.44375000
# Enumerated nodes:               0
# Total iterations:               18
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/pulp.py:1298: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/pulp.py:1298: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hy/frf0zxvn1k5_c7zh7z63995r0000gn/T/d32bc9f3afab4f2b8a4a26efae0fc901-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/hy/frf0zxvn1k5_c7zh7z63995r0000gn/T/d32bc9f3afab4f2b8a4a26efae0fc901-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 113 COLUMNS
# At line 632 RHS
# At line 741 BOUNDS
# At line 838 ENDATA
# Problem MODEL has 108 rows, 96 columns and 278 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is -2.90532e+07 - 0.00 seconds
# Cgl0003I 0 fixed, 20 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 16 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 12 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 8 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 4 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 64 rows, 66 columns (66 integer (0 of which binary)) and 202 elements
# Cbc0012I Integer solution of -29027830 found by DiveCoefficient after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0038I Full problem 64 rows 66 columns, reduced to 15 rows 14 columns
# Cbc0012I Integer solution of -29041631 found by DiveCoefficient after 6 iterations and 0 nodes (0.01 seconds)
# ...
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 113 COLUMNS
# At line 632 RHS
# At line 741 BOUNDS
# At line 838 ENDATA
# Problem MODEL has 108 rows, 96 columns and 278 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is -2.44126e+06 - 0.00 seconds
# Cgl0003I 0 fixed, 20 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 16 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 12 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 8 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 4 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 64 rows, 66 columns (66 integer (0 of which binary)) and 202 elements
# Cbc0012I Integer solution of -2435670.1 found by DiveCoefficient after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0038I Full problem 64 rows 66 columns, reduced to 6 rows 8 columns
# Cbc0031I 4 added rows had average density of 5
# Cbc0013I At root node, 31 cuts changed objective from -2441259.5 to -2435670.1 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 5 column cuts (5 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 7 row cuts average 7.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 24 row cuts average 4.7 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -2435670.076666454, took 5 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 3 variables fixed on reduced cost
# Cuts at root node changed objective from -2.44126e+06 to -2.43567e+06
# Probing was tried 1 times and created 5 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 1 times and created 7 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 1 times and created 24 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                -2435670.07666645
# Enumerated nodes:               0
# Total iterations:               5
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hy/frf0zxvn1k5_c7zh7z63995r0000gn/T/b37b92624b1641558e3b6a2a3c50d98f-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/hy/frf0zxvn1k5_c7zh7z63995r0000gn/T/b37b92624b1641558e3b6a2a3c50d98f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 113 COLUMNS
# At line 632 RHS
# At line 741 BOUNDS
# At line 838 ENDATA
# Problem MODEL has 108 rows, 96 columns and 278 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is -8.52766e+07 - 0.00 seconds
# Cgl0003I 0 fixed, 20 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 16 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 12 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 8 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 4 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 64 rows, 66 columns (66 integer (0 of which binary)) and 202 elements
# Cbc0012I Integer solution of -85272072 found by DiveCoefficient after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0038I Full problem 64 rows 66 columns, reduced to 6 rows 9 columns
# Cbc0012I Integer solution of -85273565 found by DiveCoefficient after 7 iterations and 0 nodes (0.01 seconds)
# Cbc0031I 1 added rows had average density of 3
# Cbc0013I At root node, 1 cuts changed objective from -85276589 to -85273565 in 5 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 10 column cuts (10 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 1 row cuts average 3.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 6 row cuts average 2.7 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -85273565.04499999, took 7 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 14 variables fixed on reduced cost
# Cuts at root node changed objective from -8.52766e+07 to -8.52736e+07
# Probing was tried 5 times and created 10 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 5 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 5 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 5 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 5 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 5 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 5 times and created 6 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                -85273565.04499999
# Enumerated nodes:               0
# Total iterations:               7
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hy/frf0zxvn1k5_c7zh7z63995r0000gn/T/cd1d84a5cb5c43249fafd7853a90db9f-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/hy/frf0zxvn1k5_c7zh7z63995r0000gn/T/cd1d84a5cb5c43249fafd7853a90db9f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 113 COLUMNS
# At line 632 RHS
# At line 741 BOUNDS
# At line 838 ENDATA
# Problem MODEL has 108 rows, 96 columns and 278 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is -1.17398e+08 - 0.00 seconds
# Cgl0003I 0 fixed, 20 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 16 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 12 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 8 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 4 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 64 rows, 66 columns (66 integer (0 of which binary)) and 202 elements
# Cbc0012I Integer solution of -1.1735181e+08 found by DiveCoefficient after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0038I Full problem 64 rows 66 columns, reduced to 6 rows 8 columns
# Cbc0012I Integer solution of -1.1738808e+08 found by DiveCoefficient after 5 iterations and 0 nodes (0.01 seconds)
# Cbc0031I 3 added rows had average density of 6
# Cbc0013I At root node, 3 cuts changed objective from -1.1739825e+08 to -1.1738808e+08 in 6 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 21 column cuts (21 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 7 row cuts average 6.9 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 22 row cuts average 6.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -117388082.385, took 5 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -1.17398e+08 to -1.17388e+08
# Probing was tried 6 times and created 21 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 6 times and created 7 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 6 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 6 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 6 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 6 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 6 times and created 22 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                -117388082.38500001
# Enumerated nodes:               0
# Total iterations:               5
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/hy/frf0zxvn1k5_c7zh7z63995r0000gn/T/615f5423919a4f15951bdf4c03080e6c-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/hy/frf0zxvn1k5_c7zh7z63995r0000gn/T/615f5423919a4f15951bdf4c03080e6c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 113 COLUMNS
# At line 632 RHS
# At line 741 BOUNDS
# At line 838 ENDATA
# Problem MODEL has 108 rows, 96 columns and 278 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 340249 - 0.00 seconds
# Cgl0003I 0 fixed, 20 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 16 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 12 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 8 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 4 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 64 rows, 66 columns (66 integer (0 of which binary)) and 202 elements
# Cbc0012I Integer solution of 341747.02 found by DiveCoefficient after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0038I Full problem 64 rows 66 columns, reduced to 0 rows 0 columns
# Cbc0013I At root node, 7 cuts changed objective from 340249.2 to 341747.02 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 2 row cuts average 4.0 elements, 4 column cuts (4 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 2 row cuts average 7.5 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 3 row cuts average 4.3 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 341747.0233332145, took 4 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 4 variables fixed on reduced cost
# Cuts at root node changed objective from 340249 to 341747
# Probing was tried 1 times and created 6 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 1 times and created 2 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 1 times and created 3 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                341747.02333321
# Enumerated nodes:               0
# Total iterations:               4
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01

# %%
final_optimization_df
# Out:
#       Country    Month  Available Agents  New Hires  Fired  Total Agents  \
# 0      Canada  2025-01             228.0        0.0  155.0         228.0
# 1      Canada  2025-02              73.0        0.0    0.0          73.0
# 2      Canada  2025-03              73.0        0.0    0.0          73.0
# 3      Canada  2025-04              73.0        0.0    0.0          73.0
# 4      Canada  2025-05              73.0        0.0    0.0          73.0
# ..        ...      ...               ...        ...    ...           ...
# 259  Thailand  2025-08              18.0        0.0    0.0          18.0
# 260  Thailand  2025-09              18.0        5.0    0.0          23.0
# 261  Thailand  2025-10              23.0        0.0    0.0          23.0
# 262  Thailand  2025-11              23.0        3.0    0.0          26.0
# 263  Thailand  2025-12              26.0       26.0    0.0          52.0
#
#      Assigned Advertisers  Waiting Advertisers  Dropped Advertisers  \
# 0                   371.0                  0.0                  0.0
# 1                   345.0                  0.0                  0.0
# 2                   354.0                  0.0                  0.0
# 3                   357.0                  0.0                  0.0
# 4                   370.0                  0.0                  0.0
# ..                    ...                  ...                  ...
# 259                  71.0                  0.0                  0.0
# 260                 105.0                  0.0                  0.0
# 261                 125.0                  0.0                  0.0
# 262                 105.0                 30.0                  0.0
# 263                 154.0                  0.0                  0.0
#
#      Graduated Advertisers  Total Cost ($)  Revenue Uplift ($)  \
# 0                      0.0      4945860.00          2264192.60
# 1                      0.0       371448.33          2134671.98
# 2                    371.0       371448.33          2314039.59
# 3                    345.0       371448.33          2199330.63
# 4                    354.0       371448.33          2270277.45
# ..                     ...             ...                 ...
# 259                   80.0        36433.50            82268.06
# 260                   84.0        46553.92           133797.83
# 261                   71.0        46553.92           190417.50
# 262                  105.0        52626.17           137979.45
# 263                  125.0       105252.33           191642.22
#
#      Waiting Cost Penalty ($)  Net Profit ($)
# 0                        0.00     -2681667.40
# 1                        0.00      1763223.65
# 2                        0.00      1942591.26
# 3                        0.00      1827882.30
# 4                        0.00      1898829.12
# ..                        ...             ...
# 259                      0.00        45834.56
# 260                      0.00        87243.91
# 261                      0.00       143863.58
# 262                   3285.23        85353.28
# 263                      0.00        86389.89
#
# [264 rows x 14 columns]

# %%
# Define the file path
output_csv_path = "Optimized_Staffing_Results_3.csv"

# Export the DataFrame to CSV
final_optimization_df.to_csv(output_csv_path, index=False)

print(f"File saved as {output_csv_path}")
# Out:
# File saved as Optimized_Staffing_Results_3.csv
